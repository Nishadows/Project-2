# %%
# Import SQL Alchemy
from sqlalchemy import create_engine, inspect

# Import pandas
import pandas as pd

# %%
realestate=pd.read_csv("Resources/realestate_prices_word_county_removed.csv",encoding="latin-1")

# %%
realestate.head()
# Out:
#    RegionID   RegionName State                             Metro  \
# 0      3101  Los Angeles    CA    Los Angeles-Long Beach-Anaheim
# 1       139         Cook    IL          Chicago-Naperville-Elgin
# 2      1090       Harris    TX  Houston-The Woodlands-Sugar Land
# 3      2402     Maricopa    AZ           Phoenix-Mesa-Scottsdale
# 4      2841    San Diego    CA                San Diego-Carlsbad
#
#    StateCodeFIPS  MunicipalCodeFIPS  SizeRank  1996-04  1996-05  1996-06  \
# 0              6                 37         1    113.0    113.0    113.0
# 1             17                 31         2    104.0    105.0    105.0
# 2             48                201         3     51.0     51.0     51.0
# 3              4                 13         4     62.0     62.0     62.0
# 4              6                 73         5    104.0    104.0    104.0
#
#     ...     2018-08  2018-09  2018-10  2018-11  2018-12  2019-01  2019-02  \
# ...

# %%
realestate['2000']=realestate[['2000-01','2000-02','2000-03','2000-04','2000-05','2000-06','2000-07','2000-08','2000-09','2000-10','2000-11','2000-12']].mean(axis=1)

# %%
realestate['2001']=realestate[['2001-01','2001-02','2001-03','2001-04','2001-05','2001-06','2001-07','2001-08','2001-09','2001-10','2001-11','2001-12']].mean(axis=1)

# %%
realestate['2002']=realestate[['2002-01','2002-02','2002-03','2002-04','2002-05','2002-06','2002-07','2002-08','2002-09','2002-10','2002-11','2002-12']].mean(axis=1)

# %%
realestate['2003']=realestate[['2003-01','2003-02','2003-03','2003-04','2003-05','2003-06','2003-07','2003-08','2003-09','2003-10','2003-11','2003-12']].mean(axis=1)

# %%
realestate['2004']=realestate[['2004-01','2004-02','2004-03','2004-04','2004-05','2004-06','2004-07','2004-08','2004-09','2004-10','2004-11','2004-12']].mean(axis=1)

# %%
realestate['2005']=realestate[['2005-01','2005-02','2005-03','2005-04','2005-05','2005-06','2005-07','2005-08','2005-09','2005-10','2005-11','2005-12']].mean(axis=1)

# %%
realestate['2006']=realestate[['2006-01','2006-02','2006-03','2006-04','2006-05','2006-06','2006-07','2006-08','2006-09','2006-10','2006-11','2006-12']].mean(axis=1)

# %%
realestate['2007']=realestate[['2007-01','2007-02','2007-03','2007-04','2007-05','2007-06','2007-07','2007-08','2007-09','2007-10','2007-11','2007-12']].mean(axis=1)

# %%
realestate['2008']=realestate[['2008-01','2008-02','2008-03','2008-04','2008-05','2008-06','2008-07','2008-08','2008-09','2008-10','2008-11','2008-12']].mean(axis=1)

# %%
realestate['2009']=realestate[['2009-01','2009-02','2009-03','2009-04','2009-05','2009-06','2009-07','2009-08','2009-09','2009-10','2009-11','2009-12']].mean(axis=1)

# %%
realestate['2010']=realestate[['2010-01','2010-02','2010-03','2010-04','2010-05','2010-06','2010-07','2010-08','2010-09','2010-10','2010-11','2010-12']].mean(axis=1)

# %%
realestate['2011']=realestate[['2011-01','2011-02','2011-03','2011-04','2011-05','2011-06','2011-07','2011-08','2011-09','2011-10','2011-11','2011-12']].mean(axis=1)

# %%
realestate['2012']=realestate[['2012-01','2012-02','2012-03','2012-04','2012-05','2012-06','2012-07','2012-08','2012-09','2012-10','2012-11','2012-12']].mean(axis=1)

# %%
realestate['2013']=realestate[['2013-01','2013-02','2013-03','2013-04','2013-05','2013-06','2013-07','2013-08','2013-09','2013-10','2013-11','2013-12']].mean(axis=1)

# %%
realestate['2014']=realestate[['2014-01','2014-02','2014-03','2014-04','2014-05','2014-06','2014-07','2014-08','2014-09','2014-10','2014-11','2014-12']].mean(axis=1)

# %%
realestate['2015']=realestate[['2015-01','2015-02','2015-03','2015-04','2015-05','2015-06','2015-07','2015-08','2015-09','2015-10','2015-11','2015-12']].mean(axis=1)

# %%
realestate['2016']=realestate[['2016-01','2016-02','2016-03','2016-04','2016-05','2016-06','2016-07','2016-08','2016-09','2016-10','2016-11','2016-12']].mean(axis=1)

# %%
realestate['2017']=realestate[['2017-01','2017-02','2017-03','2017-04','2017-05','2017-06','2017-07','2017-08','2017-09','2017-10','2017-11','2017-12']].mean(axis=1)

# %%
realestate['2018']=realestate[['2018-01','2018-02','2018-03','2018-04','2018-05','2018-06','2018-07','2018-08','2018-09','2018-10','2018-11','2018-12']].mean(axis=1)

# %%
new_df=realestate[[
                  'RegionName',
                'State',
                  '2000',
                  '2001',
                  '2002',
                  '2003',
                  '2004',
                  '2005',
                  '2006',
                  '2007',
                  '2008',
                  '2009',
                  '2010',
                  '2011',
                  '2012',
                  '2013',
                  '2014',
                  '2015',
                  '2016',
                  '2017',
                  '2018']].copy()
new_df.head()
# Out:
#     RegionName State        2000        2001        2002        2003  \
# 0  Los Angeles    CA  146.166667  161.500000  186.416667  226.083333
# 1         Cook    IL  121.500000  131.250000  142.333333  155.416667
# 2       Harris    TX   60.166667   59.166667   60.750000   62.750000
# 3     Maricopa    AZ   79.000000   83.833333   88.250000   93.083333
# 4    San Diego    CA  150.666667  173.000000  202.166667  242.250000
#
#          2004        2005        2006        2007     ...            2009  \
# 0  290.000000  353.000000  394.333333  378.833333     ...      268.166667
# 1  170.833333  190.083333  204.666667  204.583333     ...      159.250000
# 2   66.833333   69.833333   71.166667   73.500000     ...       69.166667
# 3  103.500000  142.333333  168.416667  158.083333     ...      100.166667
# 4  306.750000  341.833333  337.333333  313.166667     ...      230.000000
#
#          2010        2011        2012        2013        2014        2015  \
# ...

# %%
new_df = pd.melt(new_df, 
        id_vars=['RegionName','State'], 
        value_vars=['2000', '2001',"2002","2003","2004","2005","2006",
                    "2007","2008","2009","2010","2011","2012","2013",
                    "2014","2015","2016","2017","2018"])

# %%
new_df = new_df.rename(columns={
    'RegionName':"County",
    "variable":"Year",
    "value":"Price"
})
new_df
# Out:
#                County State  Year       Price
# 0         Los Angeles    CA  2000  146.166667
# 1                Cook    IL  2000  121.500000
# 2              Harris    TX  2000   60.166667
# 3            Maricopa    AZ  2000   79.000000
# 4           San Diego    CA  2000  150.666667
# 5              Orange    CA  2000  166.000000
# 6               Kings    NY  2000  171.500000
# 7          Miami-Dade    FL  2000   77.333333
# 8              Dallas    TX  2000   63.416667
# 9              Queens    NY  2000  171.250000
# 10          Riverside    CA  2000   88.833333
# 11     San Bernardino    CA  2000   83.333333
# 12              Clark    NV  2000   83.666667
# 13               King    WA  2000  141.166667
# 14              Wayne    MI  2000   82.333333
# 15            Tarrant    TX  2000   64.333333
# 16        Santa Clara    CA  2000  302.333333
# 17            Broward    FL  2000   78.500000
# 18              Bexar    TX  2000   58.250000
# ...

# %%
new_df = new_df.loc[new_df["State"].isin(["DC","MD","VA","WA"])]
filtered_df = new_df.loc[new_df["County"].isin(['Montgomery',
'Prince Georges',
'District of Columbia',
'Arlington',
'Frederick',
'Charles',
'Clarke',
'Culpeper',
'Fairfax',
'Fairfax City',
'Falls Church City',
'Fauquier',
'Calvert',
'Fredericksburg City',
'Jefferson',
'Loudoun',
'Manassas Park City',
'Prince William',
'Spotsylvania',
'Stafford',
'Warren',
    "District of Columbia",
                                           "Arlington",
                                           "Fairfax",
                                           "Loudon",
                                           "Calvert",
                                           "Prince William",
                                           "Charles",
                                          "Stafford",
                                          "Frederick",
                                          "Alexandria"])]
filtered_df
# Out:
#                      County State  Year       Price
# 35                  Fairfax    VA  2000  134.000000
# 41               Montgomery    MD  2000  126.916667
# 58           Prince Georges    MD  2000   91.833333
# 104    District of Columbia    DC  2000  128.833333
# 164          Prince William    VA  2000   98.083333
# 201                 Loudoun    VA  2000  115.416667
# 270               Frederick    MD  2000   94.250000
# 290               Arlington    VA  2000  173.500000
# 405                 Charles    MD  2000   84.500000
# 454                Stafford    VA  2000   81.666667
# 469            Spotsylvania    VA  2000   77.666667
# 563              Montgomery    VA  2000   72.333333
# 587                 Calvert    MD  2000   98.166667
# 626               Frederick    VA  2000   74.250000
# 714                Fauquier    VA  2000   97.416667
# 884                Culpeper    VA  2000   76.250000
# 1019                 Warren    VA  2000   92.666667
# ...

# %%
filtered_df.to_csv("Output/price_per_sqft.csv", index=False, header=True)

# %%
for year in
# Out:
#                   RegionName State  Year       Price
# 13               King County    WA  2000  141.166667
# 35            Fairfax County    VA  2000  134.000000
# 41         Montgomery County    MD  2000  126.916667
# 58     Prince Georges County    MD  2000   91.833333
# 66          Baltimore County    MD  2000   86.750000
# 71             Pierce County    WA  2000   98.416667
# 82          Snohomish County    WA  2000  127.500000
# 99            Baltimore City    MD  2000   52.833333
# 104     District of Columbia    DC  2000  128.833333
# 115      Anne Arundel County    MD  2000  106.083333
# 137           Spokane County    WA  2000   90.500000
# 149      Virginia Beach City    VA  2000   70.083333
# 154             Clark County    WA  2000   94.083333
# 164    Prince William County    VA  2000   98.083333
# 198      Chesterfield County    VA  2000   69.583333
# 201           Loudoun County    VA  2000  115.416667
# 205           Henrico County    VA  2000   77.583333
# ...

# %%
years = ['2000', '2001',"2002","2003","2004","2005","2006",
                    "2007","2008","2009","2010","2011","2012","2013",
                    "2014","2015","2016","2017","2018"]
# for index, row in filtered_df.iterrows():
#     hv_dict = {}
    
#     print(row["Year"])
print(years)
for y in years:
    county = {"county":y,
             "homevalue":2,
             "rentalprice":3,
             "geometry":4}
    print(county)

# json = {2000 : [county: countyname,
# 				price: homevaluesqfit,
# 				rentalprice: rentalprice,
# 				geometry: [ *list of coordinates from shapefile*]
# 			   ]
# 	   }
# Out:
# ['2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018']
# {'county': '2000', 'homevalue': 2, 'rentalprice': 3, 'geometry': 4}
# {'county': '2001', 'homevalue': 2, 'rentalprice': 3, 'geometry': 4}
# {'county': '2002', 'homevalue': 2, 'rentalprice': 3, 'geometry': 4}
# {'county': '2003', 'homevalue': 2, 'rentalprice': 3, 'geometry': 4}
# {'county': '2004', 'homevalue': 2, 'rentalprice': 3, 'geometry': 4}
# {'county': '2005', 'homevalue': 2, 'rentalprice': 3, 'geometry': 4}
# {'county': '2006', 'homevalue': 2, 'rentalprice': 3, 'geometry': 4}
# {'county': '2007', 'homevalue': 2, 'rentalprice': 3, 'geometry': 4}
# {'county': '2008', 'homevalue': 2, 'rentalprice': 3, 'geometry': 4}
# {'county': '2009', 'homevalue': 2, 'rentalprice': 3, 'geometry': 4}
# {'county': '2010', 'homevalue': 2, 'rentalprice': 3, 'geometry': 4}
# {'county': '2011', 'homevalue': 2, 'rentalprice': 3, 'geometry': 4}
# ...

# %%
import json

with open('C:\Users\emrey\OneDrive\Project-2\static\js\counties2.geojson') as data_file:    
    data = json.load(data_file)
    for v in data.values():
        print(v['x'], v['y'], v['yr'])
# Out:
#   File "<ipython-input-191-d786c6b96d63>", line 3
#     with open('C:\Users\emrey\OneDrive\Project-2\static\js\counties2.geojson') as data_file:
#              ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
import requests

query_url = "https://raw.githubusercontent.com/emreynolds9/Project-2/master/static/js/counties2.geojson"

response = requests.get(query_url).json()

# lats = []
# temp = []
# hums = []
# cloud =[]
# wndspd= []
# country =[]
# date = []
# longs = []
# good_cities = []

# recordcount = 1
# timeoutcounter = 1
# print("Beginning Data Retrieval")     
# print("-----------------------------")

for x in response:
#     print(response["features"][1]["properties"])
#     print(response["features"][1]["geometry"]['coordinates'])
#     print(response["features"])
    for y in (response["features"]):
        county=y["properties"]["NAME"]
        state=y["properties"]["STATE_NAME"]
        y["properties"]["HOME_VALUE"]=4444444444
        print(y["properties"])

#     print(response)
# Out:
# {'OBJECTID': 1, 'NAME': 'Gloucester', 'STATE_NAME': 'Virginia', 'POP2010': 36858, 'POP10_SQMI': 166.1, 'POP2012': 37481, 'POP12_SQMI': 168.917030961, 'WHITE': 32149, 'BLACK': 3197, 'AMERI_ES': 139, 'ASIAN': 286, 'HAWN_PI': 15, 'HISPANIC': 935, 'OTHER': 208, 'MULT_RACE': 864, 'MALES': 18239, 'FEMALES': 18619, 'AGE_UNDER5': 1841, 'AGE_5_9': 2209, 'AGE_10_14': 2414, 'AGE_15_19': 2612, 'AGE_20_24': 1864, 'AGE_25_34': 3871, 'AGE_35_44': 4914, 'AGE_45_54': 6615, 'AGE_55_64': 5108, 'AGE_65_74': 3221, 'AGE_75_84': 1600, 'AGE_85_UP': 589, 'MED_AGE': 42.5, 'MED_AGE_M': 41.3, 'MED_AGE_F': 43.6, 'HOUSEHOLDS': 14293, 'AVE_HH_SZ': 2.55, 'HSEHLD_1_M': 1395, 'HSEHLD_1_F': 1644, 'MARHH_CHD': 3307, 'MARHH_NO_C': 4999, 'MHH_CHILD': 393, 'FHH_CHILD': 892, 'FAMILIES': 10449, 'AVE_FAM_SZ': 2.95, 'HSE_UNITS': 15852, 'VACANT': 1559, 'OWNER_OCC': 11463, 'RENTER_OCC': 2830, 'NO_FARMS07': 159, 'AVG_SIZE07': 144, 'CROP_ACR07': 16393, 'AVG_SALE07': 56.3, 'SQMI': 221.89, 'Shape__Area': 876941517.046875, 'Shape__L
# ...

# %%
xxx = filtered_df.loc[filtered_df["County"].isin(["Arlington"])]
xxx
# Out:
#           County State  Year       Price
# 290    Arlington    VA  2000  173.500000
# 2022   Arlington    VA  2001  206.666667
# 3754   Arlington    VA  2002  245.166667
# 5486   Arlington    VA  2003  285.916667
# 7218   Arlington    VA  2004  344.500000
# 8950   Arlington    VA  2005  408.833333
# 10682  Arlington    VA  2006  418.833333
# 12414  Arlington    VA  2007  409.333333
# 14146  Arlington    VA  2008  391.333333
# 15878  Arlington    VA  2009  383.250000
# 17610  Arlington    VA  2010  382.416667
# 19342  Arlington    VA  2011  381.500000
# 21074  Arlington    VA  2012  391.666667
# 22806  Arlington    VA  2013  411.500000
# 24538  Arlington    VA  2014  423.750000
# 26270  Arlington    VA  2015  429.750000
# 28002  Arlington    VA  2016  441.166667
# 29734  Arlington    VA  2017  454.583333
# 31466  Arlington    VA  2018  469.000000
